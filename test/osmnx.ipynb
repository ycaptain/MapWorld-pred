# %%
import osmnx as ox 
ox.config(log_console=True, use_cache=True)
graph = ox.graph_from_bbox(36.2639592, 36.121277700026354, -115.153018200057588, -115.307517600000025, network_type='drive')
gdf = ox.graph_to_gdfs(graph)

# %%
#proj_graph = ox.project_graph(graph)
ox.plot_graph(graph)
#ox.save_graphml(graph, filename='vegas.graphml')
# Out:
# (<Figure size 466.913x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa3034f65f8>)

# %%
import networkx as nx
import matplotlib.pyplot as plt
